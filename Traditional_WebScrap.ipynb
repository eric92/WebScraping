# %% [markdown]
# # WEBSCRAPING (NO SELEMIUM)

# %% [markdown]
# This notebook is a basic to intermediary level web_scrapping. The purpose of this notebook is to show how to quickly
# scrape data from a web-page. If you are looking to scrape data anytime soon please noet that you should always read the terms and conditions of the
# relevant website. Although a familiarity HTML or semi-structure file (where you can learn the notion of parents and children such as xml or json) would help you to navigate and retrieve the information you want,
# I will not use much navigation in this notebook but go straight to the relevant tags and retrieve information I need instead.

# %%
from  urllib.request import urlopen as Ureq
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd
import re

# %%
# visit the url to have a look - find this website by 
my_url='https://www.scottishevents.co.uk/events/category/sport/'

# %%
# downlodaing the page
client=Ureq(my_url)

# storing the downloaded page
html_page=client.read()

#closing the connection
client.close()

# %%
# parinsg with html
page_soup= soup(html_page, 'html.parser')

# %%
print (page_soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="Just another WordPress site" name="description" property="description">
# <!-- / SEO META TAGS -->
# <noscript>
# <style type="text/css">#dawnthems-preload{display: none;}</style>
# </noscript>
# <title>Upcoming Events – Scottish Events</title>
# <link href="//fonts.googleapis.com" rel="dns-prefetch">
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.scottishevents.co.uk/feed/" rel="alternate" title="Scottish Events » Feed" type="application/rss+xml"/>
# <link href="https://www.scottishevents.co.uk/comments/feed/" rel="alternate" title="Scottish Events » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.scottishevents.co.uk/events/?ical=1" rel="alternate" title="Scottish Events » iCal Feed" type="text/calendar"/>
# <link href="https://www.scottishevents.co.uk/events/feed/" rel="alternate" title="Scottish Events » Events Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.scottishevents.co.uk\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.4"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/includes/ajax-register-login/assets/css/ajax-register-login.min.css?ver=5.4.4" id="ticketbox-register-login-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/css/common-skeleton.min.css?ver=4.12.5" id="tribe-common-skeleton-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/css/common-full.min.css?ver=4.12.5" id="tribe-common-full-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/vendor/bootstrap-datepicker/css/bootstrap-datepicker.standalone.min.css?ver=5.1.4" id="tribe-events-views-v2-bootstrap-datepicker-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/vendor/tooltipster/tooltipster.bundle.min.css?ver=4.12.5" id="tribe-tooltipster-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/css/views-skeleton.min.css?ver=5.1.4" id="tribe-events-views-v2-skeleton-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/css/views-full.min.css?ver=5.1.4" id="tribe-events-views-v2-full-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-includes/css/dashicons.min.css?ver=5.4.4" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/src/resources/css/tickets.min.css?ver=4.12.1" id="event-tickets-plus-tickets-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/css/tooltip.min.css?ver=4.12.5" id="tribe-tooltip-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/css/tickets.min.css?ver=4.12.2" id="event-tickets-tickets-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/css/rsvp-v1.min.css?ver=4.12.2" id="event-tickets-tickets-rsvp-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/views-full.min.css?ver=5.1.1" id="tribe-events-pro-views-v2-full-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/views-skeleton.min.css?ver=5.1.1" id="tribe-events-pro-views-v2-skeleton-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-includes/css/dist/block-library/style.min.css?ver=5.4.4" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/packages/woocommerce-blocks/build/style.css?ver=2.5.16" id="wc-block-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/dawnthemes-instagram/assets/css/style.min.css?ver=5.4.4" id="dawnthemes-instagram-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/revslider/public/assets/css/rs6.css?ver=6.1.8" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="rs-plugin-settings-inline-css" type="text/css">
# #rs-demo-id {}
# </style>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/css/woocommerce-layout.css?ver=4.1.0" id="woocommerce-layout-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/css/woocommerce-smallscreen.css?ver=4.1.0" id="woocommerce-smallscreen-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/css/woocommerce.css?ver=4.1.0" id="woocommerce-general-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="woocommerce-inline-inline-css" type="text/css">
# .woocommerce form .form-row .required { visibility: visible; }
# </style>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-theme.min.css?ver=5.1.1" id="tribe-events-calendar-pro-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-theme-mobile.min.css?ver=5.1.1" id="tribe-events-calendar-pro-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-full-mobile.min.css?ver=5.1.1" id="tribe-events-calendar-full-pro-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Lato&amp;ver=5.4.4" id="ticketbox-google-font-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/css/bootstrap.min.css?ver=3.3.5" id="bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/dawnthemes/assets/lib/font-awesome/css/font-awesome.min.css?ver=4.7.0" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/dawnthemes/assets/lib/elegant-icon/css/elegant-icon.css?ver=5.4.4" id="elegant-icon-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/magnific-popup/magnific-popup.css?ver=5.4.4" id="magnific-popup-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/owlcarousel/owl.theme.default.min.css?ver=2.3.2" id="owl.theme-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/owlcarousel/owl.carousel.css?ver=2.3.2" id="owl.carousel-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/slick/slick.css?ver=5.4.4" id="slick-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/css/revealer.css?ver=5.4.4" id="revealer-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/css/woocommerce.min.css?ver=1.2.9.7" id="ticketbox-woocommerce-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/css/style.min.css?ver=1.2.9.7" id="ticketbox-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='ie-css'  href='https://www.scottishevents.co.uk/wp-admin/css/ie.min.css?ver=5.4.4' type='text/css' media='all' />
# <![endif]-->
# <link href="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/style.css?ver=1.2.9.7" id="ticketbox-wp-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="ticketbox-wp-inline-css" type="text/css">
# body.style-header-2 .site-header-top{position:relative;z-index:99998;background-color:#34459d;height:80px;}
# </style>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/includes/ajax-register-login/assets/js/jquery.validate.min.js?ver=5.4.4" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var ticketbox_ajax_auth_object = {"ajaxurl":"https:\/\/www.scottishevents.co.uk\/wp-admin\/admin-ajax.php","redirecturl":"\/\/www.scottishevents.co.uk\/events\/category\/sport\/","register_redirect":"\/\/www.scottishevents.co.uk\/events\/category\/sport\/","loadingmessage":"Sending user info, please wait..."};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/includes/ajax-register-login/assets/js/ajax-register-login.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/js/underscore-before.js"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/underscore.min.js?ver=1.8.3" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/js/underscore-after.js"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/wp-util.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/js/tribe-common.min.js?ver=4.12.5" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/breakpoints.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/revslider/public/assets/js/revolution.tools.min.js?ver=6.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/revslider/public/assets/js/rs6.min.js?ver=6.1.8" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/jquery-blockui/jquery.blockUI.min.js?ver=2.70" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wc_add_to_cart_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","i18n_view_cart":"View basket","cart_url":"https:\/\/www.scottishevents.co.uk\/cart\/","is_cart":"","cart_redirect_after_add":"no"};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/frontend/add-to-cart.min.js?ver=4.1.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/js_composer/assets/js/vendors/woocommerce-add-to-cart.js?ver=6.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/dawnthemes/assets/lib/chosen-v1.3.0/chosen.jquery.min.js?ver=1.3.0" type="text/javascript"></script>
# <link href="https://www.scottishevents.co.uk/wp-json/" rel="https://api.w.org/"/>
# <link href="https://www.scottishevents.co.uk/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.scottishevents.co.uk/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.4.4" name="generator">
# <meta content="WooCommerce 4.1.0" name="generator"/>
# <meta content="v1" name="et-api-version"/><meta content="https://www.scottishevents.co.uk" name="et-api-origin"/><link href="https://www.scottishevents.co.uk/wp-json/tribe/tickets/v1/" rel="https://theeventscalendar.com/"/><meta content="v1" name="tec-api-version"/><meta content="https://www.scottishevents.co.uk" name="tec-api-origin"/><link href="https://www.scottishevents.co.uk/wp-json/tribe/events/v1/events/?categories=sport" rel="https://theeventscalendar.com/"/><meta content="Just another WordPress site" name="description" property="description">
# <!-- / SEO META TAGS -->
# <script type="text/javascript">
# 			var ticketbox_retina = 'retina='+ window.devicePixelRatio +';'+ ticketbox_retina;
# 			document.cookie = ticketbox_retina;
# 			if(document.cookie){
# 				// document.location.reload(true);
# 			}
# 			</script>
# <script type="text/javascript">
# 		var ticketbox_dt_ajaxurl = 'https://www.scottishevents.co.uk/wp-admin/admin-ajax.php';
# 	</script>
# <noscript><style>.woocommerce-product-gallery{ opacity: 1 !important; }</style></noscript>
# <style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style><meta content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress." name="generator">
# <meta content="Powered by Slider Revolution 6.1.8 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator">
# <script type="text/javascript">function setREVStartSize(e){
# 			try {
# 				var pw = document.getElementById(e.c).parentNode.offsetWidth,
# 					newh;
# 				pw = pw===0 || isNaN(pw) ? window.innerWidth : pw;
# 				e.tabw = e.tabw===undefined ? 0 : parseInt(e.tabw);
# 				e.thumbw = e.thumbw===undefined ? 0 : parseInt(e.thumbw);
# 				e.tabh = e.tabh===undefined ? 0 : parseInt(e.tabh);
# 				e.thumbh = e.thumbh===undefined ? 0 : parseInt(e.thumbh);
# 				e.tabhide = e.tabhide===undefined ? 0 : parseInt(e.tabhide);
# 				e.thumbhide = e.thumbhide===undefined ? 0 : parseInt(e.thumbhide);
# 				e.mh = e.mh===undefined || e.mh=="" || e.mh==="auto" ? 0 : parseInt(e.mh,0);
# 				if(e.layout==="fullscreen" || e.l==="fullscreen")
# 					newh = Math.max(e.mh,window.innerHeight);
# 				else{
# 					e.gw = Array.isArray(e.gw) ? e.gw : [e.gw];
# 					for (var i in e.rl) if (e.gw[i]===undefined || e.gw[i]===0) e.gw[i] = e.gw[i-1];
# 					e.gh = e.el===undefined || e.el==="" || (Array.isArray(e.el) && e.el.length==0)? e.gh : e.el;
# 					e.gh = Array.isArray(e.gh) ? e.gh : [e.gh];
# 					for (var i in e.rl) if (e.gh[i]===undefined || e.gh[i]===0) e.gh[i] = e.gh[i-1];
#
# 					var nl = new Array(e.rl.length),
# 						ix = 0,
# 						sl;
# 					e.tabw = e.tabhide>=pw ? 0 : e.tabw;
# 					e.thumbw = e.thumbhide>=pw ? 0 : e.thumbw;
# 					e.tabh = e.tabhide>=pw ? 0 : e.tabh;
# 					e.thumbh = e.thumbhide>=pw ? 0 : e.thumbh;
# 					for (var i in e.rl) nl[i] = e.rl[i]<window.innerWidth ? 0 : e.rl[i];
# 					sl = nl[0];
# 					for (var i in nl) if (sl>nl[i] && nl[i]>0) { sl = nl[i]; ix=i;}
# 					var m = pw>(e.gw[ix]+e.tabw+e.thumbw) ? 1 : (pw-(e.tabw+e.thumbw)) / (e.gw[ix]);
#
# 					newh =  (e.type==="carousel" && e.justify==="true" ? e.gh[ix] : (e.gh[ix] * m)) + (e.tabh + e.thumbh);
# 				}
#
# 				if(window.rs_init_css===undefined) window.rs_init_css = document.head.appendChild(document.createElement("style"));
# 				document.getElementById(e.c).height = newh;
# 				window.rs_init_css.innerHTML += "#"+e.c+"_wrapper { height: "+newh+"px }";
# 			} catch(e){
# 				console.log("Failure at Presize of Slider:" + e)
# 			}
# 		  };</script>
# <style id="wp-custom-css" type="text/css">
# 			h3.upcoming-events-title.ticketbox-sc-title {
# 	color:#35469d;
# 	text-transform:uppercase;
# 	font-size:2.2em;
# }
#
# .site-footer #footer-primary {
#     padding: 0;
#     background-color: #34459d;
#     background-image: url(https://www.scottishevents.co.uk/wp-content/uploads/2020/06/footer-background-imagev4.png);
#     background-repeat: no-repeat;
#     background-position: center;
# };
# }
#
# .site-footer .footer-bottom {
#     padding: 30px 0px 0px;
#     background-color: #2575bc;
# }
#
# .count {
#     display: block;
# }
#
# h2.woocommerce-loop-category__title{
#     text-align: center;
#     text-transform: uppercase;
#     font-size: 2em;
# }
#
# h1.foot-fixture-heading {
#     text-transform: uppercase;
#     text-align: center;
#     font-weight: 800;
# 	font-size: 1.6em;
# }
#
# h1.sell-tickets {
#     font-size: 1.4em;
# margin-bottom: 30px!important;
# 	}
#
# span.wpcf7-form-control-wrap radio-938 {
# 	display:block;
#
# }
#
# span.wpcf7-list-item {     margin-left: 10px; }
#
#
#
# h1.sell-tickets-legend { color: #35469d;
#     text-transform: uppercase;
#     font-size: 2.1em;
# 	    margin-bottom: 20px!important;
# 	    margin-top: 10px!important;
#     border-bottom: 1px solid;
#     padding-bottom: 10px;
# }
#
# span#version-one-wpcf7-form-control wpcf7-radio {
#
#
# }
#
# wpcf7-form-control-wpcf7-radio version-two {
#
#
# }
#
# .sell-tickets-background {
#
#     background-color: #eaeaea;
#     margin-top: 10px;
#     border: solid 1px #35469d;
#     padding: 10px;
#
# }
#
# p.sell-tickets-para{
#     font-size: 1.3em;
#
#
# }
#
# h2.home-page-main-event {
# 	color:white;
#
# }
#
# h1.popular {
#     text-align: center;
#     text-transform: uppercase;
#     margin-top: 20px;
#     margin-bottom: 20px;
#     color: #34459d;
#     font-weight: bold;
#     font-size: 2.3em;
# }
# h1.popular:after {
#     content: "";
#     display: block;
#     height: 4px;
#     width: 20%;
#     background-color: #34459d;
#     margin: 20px auto auto auto;
#     margin-top: 10px;
# }
#
#
# h1.popular-contact {
#     text-align: center;
#     text-transform: normal;
#     margin-top: 20px;
#     margin-bottom: 20px;
#     color: #34459d;
#     font-weight: bold;
#     font-size: 1.5em;
# 	font-style:italic;
# }
#
# h1.popular-upcoming {
#     text-align: center;
#     text-transform: uppercase;
#     margin-top: 20px;
#     margin-bottom: 20px;
#     color: white;
#     font-weight: bold;
#     font-size: 2.3em;
# }
# h1.popular-upcoming:after {
#     content: "";
#     display: block;
#     height: 4px;
#     width: 20%;
#     background-color: white;
#     margin: 20px auto auto auto;
#     margin-top: 10px;
# }
#
#
# h1.sell-tickets-header {
#     text-align: left;
#     text-transform: uppercase;
#     margin-top: 20px;
#     margin-bottom: 20px;
#     color: white;
#     font-weight: bold;
#     font-size: 2em;
# }
# h1.sell-tickets-header:after {
#     content: "";
#     display: block;
#     height: 4px;
#     width: 20%;
#     background-color: white;
#     margin-top: 10px;
# }
# h2#popular-links-title {
# text-shadow: 1px 1px 1px black;
#
# }
#
# h3.feature-item-title {
#     font-size: 1.6em!important;
#     color: #35469d;
# }
#
# .testimonial-carousel .testimonial-item .testimonial-item-info .testimonial-item-comment {
#     color: #34459d!important;
# }
#
#
# p.contact-text {
#     color: white;
#     text-align: center;
#     font-size: 2em;
# }
#
# a.home-contact {
#     color: #5a76d3;
#     font-weight: bold;
#     text-decoration: none;
# }
# a:hover.home-contact {
# 	color:lightgray;
# }
#
# 		</style>
# <noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript></meta></meta></meta></meta></link></meta></head>
# <body class="archive post-type-archive post-type-archive-tribe_events theme-ticketbox woocommerce-no-js tribe-events-page-template tribe-no-js tribe-filter-live tribe-events-uses-geolocation style-header-2 style-footer-1 full-width sticky-menu wpb-js-composer js-comp-ver-6.1 vc_responsive" data-rsssl="1">
# <div class="offcanvas">
# <a class="mobile-menu-toggle" href="#"><i class="fa fa-times-circle"></i></a>
# <div class="dt-sidenav-wrapper">
# <nav class="site-navigation side-navigation" id="side-navigation">
# <div class="menu-primary-menu-container"><ul class="nav-menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-7642" id="menu-item-7642"><a href="https://www.scottishevents.co.uk/">Home</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-6584" id="menu-item-6584"><a href="https://www.scottishevents.co.uk/about-us/">About Us</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6623" id="menu-item-6623"><a href="https://www.scottishevents.co.uk/instagram/">Instagram</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6581" id="menu-item-6581"><a href="https://www.scottishevents.co.uk/events/">Events</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6596" id="menu-item-6596"><a href="https://www.scottishevents.co.uk/events/list">List View</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6597" id="menu-item-6597"><a href="https://www.scottishevents.co.uk/events/month">Calendar View</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6598" id="menu-item-6598"><a href="https://www.scottishevents.co.uk/events/today">ToDay View</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6614" id="menu-item-6614"><a href="https://www.scottishevents.co.uk/featured-events/">Featured Events</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7223" id="menu-item-7223"><a href="https://www.scottishevents.co.uk/merchandise/">Merchandise</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-6591" id="menu-item-6591"><a href="https://www.scottishevents.co.uk/shop/">Shop</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6595" id="menu-item-6595"><a href="https://www.scottishevents.co.uk/shop/">Shop Products</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6622" id="menu-item-6622"><a href="https://www.scottishevents.co.uk/faqs/">FAQ’S</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6660" id="menu-item-6660"><a href="https://www.scottishevents.co.uk/upcoming-events/">Upcoming Events</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6605" id="menu-item-6605"><a href="https://www.scottishevents.co.uk/contact/">Contact</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7217" id="menu-item-7217"><a href="https://www.scottishevents.co.uk/terms-and-conditions/">T and C’s</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7545" id="menu-item-7545"><a href="https://www.scottishevents.co.uk/sell-your-tickets/">Sell Your Tickets</a></li>
# </ul></div> </nav>
# </div>
# </div>
# <div class="hfeed site" id="l-page">
# <div class="offcanvas-overlay"></div>
# <a class="skip-link screen-reader-text" href="#content">Skip to content</a>
# <header class="site-header" id="masthead">
# <div class="site-header-top">
# <div class="container">
# <div class="site-info-left">
# <ul class="ticketbox_dt_social_profile ulclear">
# <li><a href="#" target="_blank" title="facebook"><i class="fa fa-facebook"></i></a></li>
# <li><a href="#" target="_blank" title="twitter"><i class="fa fa-twitter"></i></a></li>
# </ul>
# </div>
# <div class="logo-wrap site-info-center">
# <h1 class="site-title">
# <a class="site-logo" href="https://www.scottishevents.co.uk/" rel="home">
# <img alt="Upcoming EventsScottish Events" class="logo" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/06/events-scotland.png"/>
# </a>
# </h1>
# </div>
# <div class="site-info-right">
# <ul class="site-info-content">
# <li> <ul class="header-minicart" id="ticketbox-header-minicart">
# <li class="minicart">
# <a class="cart-contents" href="https://www.scottishevents.co.uk/cart/" title="View your shopping cart">
# <span class="count">0</span>
# </a>
# </li>
# <li>
# <div class="widget woocommerce widget_shopping_cart"><div class="widget_shopping_cart_content"></div></div> </li>
# </ul>
# </li>
# <li><div class="ticketbox_register_login"><a href="#" id="ticketbox_show_login" style="cursor:pointer" title="Join us now"><i aria-hidden="true" class="fa fa-bookmark"></i>Join us now</a></div></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="page-hero-wrap has-header-background" style="background-image:url(https://www.scottishevents.co.uk/wp-content/uploads/2020/08/man-utrd-v-fulham-fixture-badges.png);">
# <div class="page-heading">
# <div class="container">
# <div class="dt_breadcrumbs">
# <div class="dt_breadcrumb__wrapper clearfix">
# <div class="row"><div class="col-md-8 col-sm-8"><h2 class="breadcrumbs-title"></h2></div><div class="breadcrumbs col-md-4 col-sm-4 hidden-xs"></div></div><!-- .breadcrumbs --> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="top-header">
# <div id="top-header-content">
# <div class="container">
# <div class="top-header-content-wrap">
# <div id="dt-main-menu">
# <div class="menu-toggle"><i class="fa fa-bars"></i></div>
# <div class="header-main">
# <div class="dt-mainnav-wrapper">
# <nav class="site-navigation primary-navigation dawnthemes-navigation-wrap" id="primary-navigation">
# <div class="megamenu ticketbox-megamenu hidden-mobile" id="dt-megamenu"><ul class="menu main-menu" data-theme-location="" id="menu-primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home level0 list-style" id="mega-menu-item-7642"><a href="https://www.scottishevents.co.uk/">Home</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6584"><a href="https://www.scottishevents.co.uk/about-us/">About Us</a>
# <ul class="sub-menu sub-menu-list level0">
# <li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1"><a href="https://www.scottishevents.co.uk/instagram/">Instagram</a></li></ul></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6581"><a href="https://www.scottishevents.co.uk/events/">Events</a>
# <ul class="sub-menu sub-menu-list level0">
# <li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1"><a href="https://www.scottishevents.co.uk/events/list">List View</a></li><li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1"><a href="https://www.scottishevents.co.uk/events/month">Calendar View</a></li><li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1"><a href="https://www.scottishevents.co.uk/events/today">ToDay View</a></li><li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1"><a href="https://www.scottishevents.co.uk/featured-events/">Featured Events</a></li></ul></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7223"><a href="https://www.scottishevents.co.uk/merchandise/">Merchandise</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6591"><a href="https://www.scottishevents.co.uk/shop/">Shop</a>
# <ul class="sub-menu sub-menu-list level0">
# <li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1"><a href="https://www.scottishevents.co.uk/shop/">Shop Products</a></li></ul></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6622"><a href="https://www.scottishevents.co.uk/faqs/">FAQ’S</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6660"><a href="https://www.scottishevents.co.uk/upcoming-events/">Upcoming Events</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6605"><a href="https://www.scottishevents.co.uk/contact/">Contact</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7217"><a href="https://www.scottishevents.co.uk/terms-and-conditions/">T and C’s</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7545"><a href="https://www.scottishevents.co.uk/sell-your-tickets/">Sell Your Tickets</a></li> </ul></div> </nav>
# </div>
# </div>
# </div>
# <div class="top-header-search_form"><div class="navbar-search navbar-search-ink"><div class="navbar-searchform navbar-searchform-ink"><div class="navbar-searchform-wrap"><form action="https://www.scottishevents.co.uk/" class="search-ajax" id="navbar-searchform" method="get" role="search">
# <label class="sr-only">Search</label>
# <input autocomplete="off" class="form-control searchinput" id="navbar-searchform-s" name="s" placeholder="Search and hit enter..." type="search" value=""/>
# <input class="hidden" id="navbar-searchform-submit" name="submit" type="submit" value="Search"/>
# <input name="post_type" type="hidden" value="any"/>
# <input name="tax" type="hidden" value=""/>
# </form><div class="searchform-result"></div></div><i class="top-searchform-icon"></i></div></div></div>
# </div>
# </div>
# </div>
# </div>
# </header><!-- #masthead -->
# <div id="dawnthemes-page">
# <div class="container main-container">
# <div class="wrapper site-main clearfix" id="main"><div class="tribe-common tribe-events tribe-events-view tribe-events-view--list" data-js="tribe-events-view" data-view-breakpoint-pointer="04b20fe3-144f-475c-8419-91bb683ffff4" data-view-manage-url="1" data-view-rest-nonce="e355e7b8eb" data-view-rest-url="https://www.scottishevents.co.uk/wp-json/tribe/views/v2/html">
# <div class="tribe-common-l-container tribe-events-l-container">
# <div aria-live="assertive" class="tribe-events-view-loader tribe-common-a11y-hidden" role="alert">
# <div class="tribe-events-view-loader__dots tribe-common-c-loader">
# <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--first"></div>
# <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--second"></div>
# <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--third"></div>
# </div>
# </div>
# <script type="application/ld+json">
# [{"@context":"http://schema.org","@type":"Event","name":"Ayr Races","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/06/ayr-races.jpg","url":"https://www.scottishevents.co.uk/event/ayr-races/","startDate":"2020-09-17T12:00:00+01:00","endDate":"2021-09-19T17:00:00+01:00","location":{"@type":"Place","name":"Ayr Racecourse","description":"","url":"https://www.scottishevents.co.uk/venue/ayr-racecourse/","address":{"@type":"PostalAddress","streetAddress":"Whitletts Road","addressLocality":"Ayr","postalCode":"KA80JE","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Hamilton Academicals","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-hamilton-academicals/","startDate":"2020-11-06T19:30:00+00:00","endDate":"2021-08-06T21:30:00+01:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Motherwell","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-motherwell/","startDate":"2020-12-19T15:00:00+00:00","endDate":"2021-12-19T17:00:00+00:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Celtic","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-celtic/","startDate":"2021-01-02T12:30:00+00:00","endDate":"2021-01-02T15:00:00+00:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Hibs v Livingstone","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/08/hibs-v-livingston-fixture-badges.png","url":"https://www.scottishevents.co.uk/event/hibs-v-livingstone/","startDate":"2021-01-02T15:00:00+00:00","endDate":"2021-01-02T17:00:00+00:00","location":{"@type":"Place","name":"Hibernian Fc","description":"","url":"https://www.scottishevents.co.uk/venue/hibernian-fc/","address":{"@type":"PostalAddress","streetAddress":"Easter Road","addressLocality":"Edinburgh","postalCode":"EH75QG","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Newcastle v Leicester","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/08/newcastle-v-leicester-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/newcastle-v-leicester/","startDate":"2021-01-02T15:00:00+00:00","endDate":"2021-01-02T17:00:00+00:00","location":{"@type":"Place","name":"St James Park","description":"","url":"https://www.scottishevents.co.uk/venue/st-james-park/","address":{"@type":"PostalAddress","streetAddress":"Barrack Road","addressLocality":"Newcastle","postalCo ...
# </script>
# <script data-js="tribe-events-view-data" type="application/json">
# 	{"slug":"list","prev_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/?eventDisplay=past","next_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/page\/2\/","view_class":"Tribe\\Events\\Views\\V2\\Views\\List_View","view_slug":"list","view_label":"List","view":{},"title":"Search Results for &#8220;&#8221; &#8211; Scottish Events","events":[7050,7402,7412,7420,7896,7917,8022,7958,7898,7960,8024,7900],"url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","url_event_date":false,"bar":{"keyword":"","date":""},"today":"2021-01-01 00:00:00","now":"2021-01-01 20:35:17","request_date":{"date":"2021-01-01 00:00:00.000000","timezone_type":3,"timezone":"Europe\/London"},"rest_url":"https:\/\/www.scottishevents.co.uk\/wp-json\/tribe\/views\/v2\/html","rest_nonce":"e355e7b8eb","should_manage_url":true,"today_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","prev_label":"","next_label":"","date_formats":{"compact":"n\/j\/Y","month_and_year_compact":"n\/j\/Y","month_and_year":"F Y","time_range_separator":" - ","date_time_separator":" @ "},"messages":[],"start_of_week":"1","breadcrumbs":[{"link":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","label":"Events"},{"link":"","label":"Sport"}],"before_events":"","after_events":"\n<!--\nThis calendar is powered by The Events Calendar.\nhttp:\/\/m.tri.be\/18wn\n-->\n","display_events_bar":true,"disable_event_search":false,"live_refresh":true,"ical":{"display_link":true,"link":{"url":"https:\/\/www.scottishevents.co.uk\/events\/?ical=1","text":"Export Events","title":"Use this to share calendar data with Google Calendar, Apple iCal and other compatible apps"}},"container_classes":["tribe-common","tribe-events","tribe-events-view","tribe-events-view--list"],"container_data":[],"is_past":false,"breakpoints":{"xsmall":500,"medium":768,"full":960},"breakpoint_pointer":"04b20fe3-144f-475c-8419-91bb683ffff4","is_initial_load":true,"public_views":{"list":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\List_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","view_label":"List"},"month":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\Month_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/month\/","view_label":"Month"},"day":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\Day_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/today\/","view_label":"Day"},"photo":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Photo_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/photo\/","view_label":"Photo"},"week":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Week_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/week\/","view_label":"Week"},"map":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Map_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/map\/","view_label":"Map"}},"show_latest_past":true,"show_now":true,"now_label":"Now","now_label_mobile":"Now","show_end":true,"selected_start_datetime":"2021-01-01","selected_start_date_mobile":"1\/1\/2021","selected_start_date_label":"January 1","selected_end_datetime":"2021-01-27","selected_end_date_mobile":"1\/27\/2021","selected_end_date_label":"January 27","datepicker_date":"1\/1\/2021","json_ld_data":"<script type=\"application\/ld+json\">\r\n[{\"@context\":\"http:\/\/schema.org\",\"@type\":\"Event\",\"name\":\"Ayr Races\",\"description\":\"\",\"image\":\"https:\/\/www.scottishevents.co.uk\/wp-content\/uploads\/2020\/06\/ayr-races.jpg\",\"url\":\"https:\/\/www.scottishevents.co.uk\/event\/ayr-races\/\",\"startDate\":\"2020-09-17T12:00:00+01:00\",\"endDate\":\"2021-09-19T17:00:00+01:00\",\"location\":{\"@type\":\"Place\",\"name\":\"Ayr Racecourse\",\"description\":\"\",\"url\":\"https:\/\/www.scottishevents.co.uk\/venue\/ayr-racecourse\/\",\"address\":{\"@type\":\"Posta ...
# <header class="tribe-events-header tribe-events-header--has-event-search">
# <div class="tribe-events-header__breadcrumbs tribe-events-c-breadcrumbs">
# <ol class="tribe-events-c-breadcrumbs__list">
# <li class="tribe-events-c-breadcrumbs__list-item">
# <a class="tribe-events-c-breadcrumbs__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/">
# 		Events	</a>
# </li>
# <li class="tribe-events-c-breadcrumbs__list-item">
# <span class="tribe-events-c-breadcrumbs__list-item-text">
# 		Sport	</span>
# </li>
# </ol>
# </div>
# <div class="tribe-events-header__events-bar tribe-events-c-events-bar tribe-events-c-events-bar--border" data-js="tribe-events-events-bar">
# <h2 class="tribe-common-a11y-visual-hide">
# 		Events Search and Views Navigation	</h2>
# <button aria-controls="tribe-events-search-filter-container" aria-expanded="false" aria-selected="false" class="tribe-events-c-events-bar__search-button" data-js="tribe-events-search-button">
# <span class="tribe-events-c-events-bar__search-button-icon tribe-common-svgicon"></span>
# <span class="tribe-events-c-events-bar__search-button-text tribe-common-a11y-visual-hide">
# 		Search	</span>
# </button>
# <div class="tribe-events-c-events-bar__search-filters-container" data-js="tribe-events-search-filters-container" id="tribe-events-search-filters-container">
# <div class="tribe-events-c-events-bar__search" data-js="tribe-events-events-bar-tabpanel tribe-events-events-bar-search" id="tribe-events-events-bar-search">
# <form class="tribe-events-c-search tribe-events-c-events-bar__search-form" data-js="tribe-events-view-form" method="get" role="search">
# <input id="tribe-events-views[_wpnonce]" name="tribe-events-views[_wpnonce]" type="hidden" value="e355e7b8eb"/><input name="_wp_http_referer" type="hidden" value="/events/category/sport/list/"/> <input name="tribe-events-views[url]" type="hidden" value="https://www.scottishevents.co.uk/events/category/sport/list/"/>
# <div class="tribe-events-c-search__input-group">
# <div class="tribe-common-form-control-text tribe-events-c-search__input-control tribe-events-c-search__input-control--keyword" data-js="tribe-events-events-bar-input-control">
# <label class="tribe-common-form-control-text__label" for="tribe-events-events-bar-keyword">
# 		Enter Keyword. Search for Events by Keyword.	</label>
# <input aria-label="Enter Keyword. Search for events by Keyword." class="tribe-common-form-control-text__input tribe-events-c-search__input tribe-events-c-search__input--icon" data-js="tribe-events-events-bar-input-control-input" id="tribe-events-events-bar-keyword" name="tribe-events-views[tribe-bar-search]" placeholder="Search for events" type="text" value=""/>
# </div>
# <div class="tribe-common-form-control-text tribe-events-c-search__input-control tribe-events-c-search__input-control--location" data-js="tribe-events-events-bar-input-control">
# <label class="tribe-common-form-control-text__label" for="tribe-events-events-bar-location">
# 		Enter Location. Search for Events by Location.	</label>
# <input aria-label="Enter Location. Search for Events by Location." class="tribe-common-form-control-text__input tribe-events-c-search__input tribe-events-c-search__input--icon" data-js="tribe-events-events-bar-input-control-input" id="tribe-events-events-bar-location" name="tribe-events-views[tribe-bar-location]" placeholder="In a location" type="text" value=""/>
# </div>
# </div>
# <button class="tribe-common-c-btn tribe-events-c-search__button" name="submit-bar" type="submit">
# 	Find Events</button>
# </form>
# </div>
# </div>
# <div class="tribe-events-c-events-bar__views">
# <h3 class="tribe-common-a11y-visual-hide">
# 		Event Views Navigation	</h3>
# <div class="tribe-events-c-view-selector tribe-events-c-view-selector--labels" data-js="tribe-events-view-selector">
# <button class="tribe-events-c-view-selector__button" data-js="tribe-events-view-selector-button">
# <span class="tribe-events-c-view-selector__button-icon tribe-common-svgicon tribe-common-svgicon--list"></span>
# <span class="tribe-events-c-view-selector__button-text tribe-common-a11y-visual-hide">
# 				List			</span>
# </button>
# <div class="tribe-events-c-view-selector__content" data-js="tribe-events-view-selector-list-container" id="tribe-events-view-selector-content">
# <ul class="tribe-events-c-view-selector__list">
# <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--list tribe-events-c-view-selector__list-item--active">
# <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/">
# <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--list"></span>
# <span class="tribe-events-c-view-selector__list-item-text">
# 			List		</span>
# </a>
# </li>
# <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--month">
# <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/month/">
# <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--month"></span>
# <span class="tribe-events-c-view-selector__list-item-text">
# 			Month		</span>
# </a>
# </li>
# <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--day">
# <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/today/">
# <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--day"></span>
# <span class="tribe-events-c-view-selector__list-item-text">
# 			Day		</span>
# </a>
# </li>
# <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--photo">
# <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/photo/">
# <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--photo"></span>
# <span class="tribe-events-c-view-selector__list-item-text">
# 			Photo		</span>
# </a>
# </li>
# <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--week">
# ...
# <a class="go-to-top" href="#"><i class="fa fa-angle-up"></i>Top</a> <form action="login" class="ticketbox-ajax-auth" id="ticketbox-ajax-auth-login" method="post">
# <h1>Login</h1>
# <hr/>
# <p class="status"></p>
# <input id="security" name="security" type="hidden" value="96938d2921"><input name="_wp_http_referer" type="hidden" value="/events/category/sport/list/">
# <div><label for="username">Username</label>
# <div style="float:right;"><a class="text-link" id="pop_signup" style="cursor:pointer;">Create an Account!</a></div>
# <input class="required" id="username" name="username" placeholder="Username" type="text"/></div>
# <div><label for="password">Password</label>
# <input class="required" id="password" name="password" placeholder="Password" type="password"/></div>
# <input class="button" name="login" type="submit" value="Login"/>
# <a class="text-link" href="https://www.scottishevents.co.uk/my-account/lost-password/" id="pop_forgot">Forgot Password?</a>
# <a class="close" href="#"><span aria-hidden="true">×</span></a>
# </input></input></form>
# <form action="register" class="ticketbox-ajax-auth" id="ticketbox-ajax-auth-register" method="post">
# <div class="alert alert-warning">Registration is disabled.</div>
# <hr/>
# <a class="text-link" id="pop_login" style="cursor:pointer">Want to Login?</a>
# <a class="close" href="#"><span aria-hidden="true">×</span></a>
# </form>
# <form action="forgot_password" class="ticketbox-ajax-auth" id="ticketbox-ajax-auth-forgot_password" method="post">
# <h1>Forgot Password?</h1>
# <hr/>
# <p class="status"></p>
# <input id="forgotsecurity" name="forgotsecurity" type="hidden" value="97ca8c0c99"><input name="_wp_http_referer" type="hidden" value="/events/category/sport/list/">
# <div><label for="user_login">Username or Email</label>
# <input class="required" id="user_login" name="user_login" placeholder="Username or email" type="text"/></div>
# <input class="button" name="forgot_password" type="submit" value="Get Password"/>
# <a class="close" href="#" style="cursor:pointer"><span aria-hidden="true">×</span></a>
# </input></input></form>
# <script> /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"},"registration_prompt":"There is unsaved attendee information. Are you sure you want to continue?"};/* ]]> */ </script> <script type="text/javascript">
# 		var c = document.body.className;
# 		c = c.replace(/woocommerce-no-js/, 'woocommerce-js');
# 		document.body.className = c;
# 	</script>
# <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/widget-theme.min.css?ver=5.1.1" id="widget-calendar-pro-style-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/vendor/bootstrap-datepicker/js/bootstrap-datepicker.min.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/vendor/jquery.cookie/jquery.cookie.js?ver=4.12.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/vendor/jquery.deparam/jquery.deparam.js?ver=4.12.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var TribeTicketsPlus = {"ajaxurl":"https:\/\/www.scottishevents.co.uk\/wp-admin\/admin-ajax.php","save_attendee_info_nonce":"9b3d89b410"};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/src/resources/js/meta.min.js?ver=4.12.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/src/resources/js/attendees-list.min.js?ver=4.12.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/draggable.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/vendor/nanoscroller/jquery.nanoscroller.min.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-grid-scroller.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/datepicker.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/datepicker-pro.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/toggle-recurrence.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/js/ticket-details.min.js?ver=4.12.2" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/vendor/tooltipster/tooltipster.bundle.min.js?ver=4.12.5" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/tooltip.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/tooltip-pro.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/js/rsvp.min.js?ver=4.12.2" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/multiday-events.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/multiday-events-pro.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-no-venue-modal.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/vendor/swiper/dist/js/swiper.min.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-provider-google-maps.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/accordion.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-multiday-toggle.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-event-link.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-events-scroller.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-day-selector.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-events.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/js/utils/query-string.js?ver=4.12.5" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/viewport.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/view-selector.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/navigation-scroll.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/month-mobile-events.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/month-grid.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/events-bar.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/events-bar-inputs.js?ver=5.1.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/manager.js?ver=5.1.4" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.scottishevents.co.uk\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.9" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/js-cookie/js.cookie.min.js?ver=2.1.4" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var woocommerce_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%"};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/frontend/woocommerce.min.js?ver=4.1.0" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wc_cart_fragments_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","cart_hash_key":"wc_cart_hash_23d62af59e1a03a30f100f510c63c31a","fragment_name":"wc_fragments_23d62af59e1a03a30f100f510c63c31a","request_timeout":"5000"};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/frontend/cart-fragments.min.js?ver=4.1.0" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var dt_megamenu = {"ajax_url":"https:\/\/www.scottishevents.co.uk\/wp-admin\/admin-ajax.php","ajax_loader":"","ajax_enabled":"0"};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/includes/megamenu/js/megamenu.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/js/bootstrap.min.js?ver=3.5.5" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/chosen/ajax-chosen.jquery.min.js?ver=1.0.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.appear.min.js?ver=1.0.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/typed.min.js?ver=1.0.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/easing.min.js?ver=1.3.0" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/waypoints.min.js?ver=2.0.5" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.countTo.min.js?ver=2.0.2" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.transit.min.js?ver=0.9.12" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/ProgressCircle.min.js?ver=2.0.2" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/magnific-popup/jquery.magnific-popup.min.js?ver=0.9.9" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/widget-countdown.min.js?ver=5.1.1" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/owlcarousel/owl.carousel.min.js?ver=2.3.2" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/helpers/jquery.ba-throttle-debounce.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.browser.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/anime.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/scrollMonitor.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/main.min.js?ver=5.4.4" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/js/plugins.js?ver=1.2.9.7" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var DawnThemesL10n = {"ajax_url":"\/wp-admin\/admin-ajax.php","protocol":"https","navbarFixedHeight":"50","breakpoint":"900","nav_breakpoint":"900","is_mobile_theme":"no","cookie_path":"\/","screen_sm":"768","screen_md":"992","screen_lg":"1200","next":"Next","prev":"Prev","touch_animate":"1","logo_retina":"","ajax_finishedMsg":"All posts displayed","ajax_msgText":"Loading the next set of posts...","woocommerce":"1","imageLazyLoading":"1","add_to_wishlist_text":"","user_logged_in":"0","loadingmessage":"Sending info, please wait..."};
# /* ]]> */
# </script>
# <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/js/script.min.js?ver=1.2.9.7" type="text/javascript"></script>
# <script src="https://www.scottishevents.co.uk/wp-includes/js/wp-embed.min.js?ver=5.4.4" type="text/javascript"></script>
# </body>
# </html>

# %%
# try to print to the body without prettifying
print (page_soup.body.prettify())
# Out:
# <body class="archive post-type-archive post-type-archive-tribe_events theme-ticketbox woocommerce-no-js tribe-events-page-template tribe-no-js tribe-filter-live tribe-events-uses-geolocation style-header-2 style-footer-1 full-width sticky-menu wpb-js-composer js-comp-ver-6.1 vc_responsive" data-rsssl="1">
#  <div class="offcanvas">
#   <a class="mobile-menu-toggle" href="#">
#    <i class="fa fa-times-circle">
#    </i>
#   </a>
#   <div class="dt-sidenav-wrapper">
#    <nav class="site-navigation side-navigation" id="side-navigation">
#     <div class="menu-primary-menu-container">
#      <ul class="nav-menu" id="primary-menu">
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-7642" id="menu-item-7642">
#        <a href="https://www.scottishevents.co.uk/">
#         Home
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-6584" id="menu-item-6584">
#        <a href="https://www.scottishevents.co.uk/about-us/">
#         About Us
#        </a>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6623" id="menu-item-6623">
#          <a href="https://www.scottishevents.co.uk/instagram/">
#           Instagram
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6581" id="menu-item-6581">
#        <a href="https://www.scottishevents.co.uk/events/">
#         Events
#        </a>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6596" id="menu-item-6596">
#          <a href="https://www.scottishevents.co.uk/events/list">
#           List View
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6597" id="menu-item-6597">
#          <a href="https://www.scottishevents.co.uk/events/month">
#           Calendar View
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6598" id="menu-item-6598">
#          <a href="https://www.scottishevents.co.uk/events/today">
#           ToDay View
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6614" id="menu-item-6614">
#          <a href="https://www.scottishevents.co.uk/featured-events/">
#           Featured Events
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7223" id="menu-item-7223">
#        <a href="https://www.scottishevents.co.uk/merchandise/">
#         Merchandise
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-6591" id="menu-item-6591">
#        <a href="https://www.scottishevents.co.uk/shop/">
#         Shop
#        </a>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6595" id="menu-item-6595">
#          <a href="https://www.scottishevents.co.uk/shop/">
#           Shop Products
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6622" id="menu-item-6622">
#        <a href="https://www.scottishevents.co.uk/faqs/">
#         FAQ’S
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6660" id="menu-item-6660">
#        <a href="https://www.scottishevents.co.uk/upcoming-events/">
#         Upcoming Events
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6605" id="menu-item-6605">
#        <a href="https://www.scottishevents.co.uk/contact/">
#         Contact
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7217" id="menu-item-7217">
#        <a href="https://www.scottishevents.co.uk/terms-and-conditions/">
#         T and C’s
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7545" id="menu-item-7545">
#        <a href="https://www.scottishevents.co.uk/sell-your-tickets/">
#         Sell Your Tickets
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </div>
#  </div>
#  <div class="hfeed site" id="l-page">
#   <div class="offcanvas-overlay">
#   </div>
#   <a class="skip-link screen-reader-text" href="#content">
#    Skip to content
#   </a>
#   <header class="site-header" id="masthead">
#    <div class="site-header-top">
#     <div class="container">
#      <div class="site-info-left">
#       <ul class="ticketbox_dt_social_profile ulclear">
#        <li>
#         <a href="#" target="_blank" title="facebook">
#          <i class="fa fa-facebook">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="#" target="_blank" title="twitter">
#          <i class="fa fa-twitter">
#          </i>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="logo-wrap site-info-center">
#       <h1 class="site-title">
#        <a class="site-logo" href="https://www.scottishevents.co.uk/" rel="home">
#         <img alt="Upcoming EventsScottish Events" class="logo" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/06/events-scotland.png"/>
#        </a>
#       </h1>
#      </div>
#      <div class="site-info-right">
#       <ul class="site-info-content">
#        <li>
#         <ul class="header-minicart" id="ticketbox-header-minicart">
#          <li class="minicart">
#           <a class="cart-contents" href="https://www.scottishevents.co.uk/cart/" title="View your shopping cart">
#            <span class="count">
#             0
#            </span>
#           </a>
#          </li>
#          <li>
#           <div class="widget woocommerce widget_shopping_cart">
#            <div class="widget_shopping_cart_content">
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <div class="ticketbox_register_login">
#          <a href="#" id="ticketbox_show_login" style="cursor:pointer" title="Join us now">
#           <i aria-hidden="true" class="fa fa-bookmark">
#           </i>
#           Join us now
#          </a>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="page-hero-wrap has-header-background" style="background-image:url(https://www.scottishevents.co.uk/wp-content/uploads/2020/08/man-utrd-v-fulham-fixture-badges.png);">
#     <div class="page-heading">
#      <div class="container">
#       <div class="dt_breadcrumbs">
#        <div class="dt_breadcrumb__wrapper clearfix">
#         <div class="row">
#          <div class="col-md-8 col-sm-8">
#           <h2 class="breadcrumbs-title">
#           </h2>
#          </div>
#          <div class="breadcrumbs col-md-4 col-sm-4 hidden-xs">
#          </div>
#         </div>
#         <!-- .breadcrumbs -->
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="top-header">
#     <div id="top-header-content">
#      <div class="container">
#       <div class="top-header-content-wrap">
#        <div id="dt-main-menu">
#         <div class="menu-toggle">
#          <i class="fa fa-bars">
#          </i>
#         </div>
#         <div class="header-main">
#          <div class="dt-mainnav-wrapper">
#           <nav class="site-navigation primary-navigation dawnthemes-navigation-wrap" id="primary-navigation">
#            <div class="megamenu ticketbox-megamenu hidden-mobile" id="dt-megamenu">
#             <ul class="menu main-menu" data-theme-location="" id="menu-primary-menu">
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home level0 list-style" id="mega-menu-item-7642">
#               <a href="https://www.scottishevents.co.uk/">
#                Home
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6584">
#               <a href="https://www.scottishevents.co.uk/about-us/">
#                About Us
#               </a>
#               <ul class="sub-menu sub-menu-list level0">
#                <li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1">
#                 <a href="https://www.scottishevents.co.uk/instagram/">
#                  Instagram
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6581">
#               <a href="https://www.scottishevents.co.uk/events/">
#                Events
#               </a>
#               <ul class="sub-menu sub-menu-list level0">
#                <li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1">
#                 <a href="https://www.scottishevents.co.uk/events/list">
#                  List View
#                 </a>
#                </li>
#                <li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1">
#                 <a href="https://www.scottishevents.co.uk/events/month">
#                  Calendar View
#                 </a>
#                </li>
#                <li class="menu-item level1 menu-item menu-item-type-custom menu-item-object-custom level1">
#                 <a href="https://www.scottishevents.co.uk/events/today">
#                  ToDay View
#                 </a>
#                </li>
#                <li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1">
#                 <a href="https://www.scottishevents.co.uk/featured-events/">
#                  Featured Events
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7223">
#               <a href="https://www.scottishevents.co.uk/merchandise/">
#                Merchandise
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children level0 menu-item-has-sub-content list-style" id="mega-menu-item-6591">
#               <a href="https://www.scottishevents.co.uk/shop/">
#                Shop
#               </a>
#               <ul class="sub-menu sub-menu-list level0">
#                <li class="menu-item level1 menu-item menu-item-type-post_type menu-item-object-page level1">
#                 <a href="https://www.scottishevents.co.uk/shop/">
#                  Shop Products
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6622">
#               <a href="https://www.scottishevents.co.uk/faqs/">
#                FAQ’S
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6660">
#               <a href="https://www.scottishevents.co.uk/upcoming-events/">
#                Upcoming Events
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-6605">
#               <a href="https://www.scottishevents.co.uk/contact/">
#                Contact
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7217">
#               <a href="https://www.scottishevents.co.uk/terms-and-conditions/">
#                T and C’s
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page level0 list-style" id="mega-menu-item-7545">
#               <a href="https://www.scottishevents.co.uk/sell-your-tickets/">
#                Sell Your Tickets
#               </a>
#              </li>
#             </ul>
#            </div>
#           </nav>
#          </div>
#         </div>
#        </div>
#        <div class="top-header-search_form">
#         <div class="navbar-search navbar-search-ink">
#          <div class="navbar-searchform navbar-searchform-ink">
#           <div class="navbar-searchform-wrap">
#            <form action="https://www.scottishevents.co.uk/" class="search-ajax" id="navbar-searchform" method="get" role="search">
#             <label class="sr-only">
#              Search
#             </label>
#             <input autocomplete="off" class="form-control searchinput" id="navbar-searchform-s" name="s" placeholder="Search and hit enter..." type="search" value=""/>
#             <input class="hidden" id="navbar-searchform-submit" name="submit" type="submit" value="Search"/>
#             <input name="post_type" type="hidden" value="any"/>
#             <input name="tax" type="hidden" value=""/>
#            </form>
#            <div class="searchform-result">
#            </div>
#           </div>
#           <i class="top-searchform-icon">
#           </i>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <!-- #masthead -->
#   <div id="dawnthemes-page">
#    <div class="container main-container">
#     <div class="wrapper site-main clearfix" id="main">
#      <div class="tribe-common tribe-events tribe-events-view tribe-events-view--list" data-js="tribe-events-view" data-view-breakpoint-pointer="04b20fe3-144f-475c-8419-91bb683ffff4" data-view-manage-url="1" data-view-rest-nonce="e355e7b8eb" data-view-rest-url="https://www.scottishevents.co.uk/wp-json/tribe/views/v2/html">
#       <div class="tribe-common-l-container tribe-events-l-container">
#        <div aria-live="assertive" class="tribe-events-view-loader tribe-common-a11y-hidden" role="alert">
#         <div class="tribe-events-view-loader__dots tribe-common-c-loader">
#          <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--first">
#          </div>
#          <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--second">
#          </div>
#          <div class="tribe-common-c-loader__dot tribe-common-c-loader__dot--third">
#          </div>
#         </div>
#        </div>
#        <script type="application/ld+json">
#         [{"@context":"http://schema.org","@type":"Event","name":"Ayr Races","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/06/ayr-races.jpg","url":"https://www.scottishevents.co.uk/event/ayr-races/","startDate":"2020-09-17T12:00:00+01:00","endDate":"2021-09-19T17:00:00+01:00","location":{"@type":"Place","name":"Ayr Racecourse","description":"","url":"https://www.scottishevents.co.uk/venue/ayr-racecourse/","address":{"@type":"PostalAddress","streetAddress":"Whitletts Road","addressLocality":"Ayr","postalCode":"KA80JE","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Hamilton Academicals","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-hamilton-academicals/","startDate":"2020-11-06T19:30:00+00:00","endDate":"2021-08-06T21:30:00+01:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Motherwell","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-motherwell/","startDate":"2020-12-19T15:00:00+00:00","endDate":"2021-12-19T17:00:00+00:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Rangers v Celtic","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/rangers-v-celtic/","startDate":"2021-01-02T12:30:00+00:00","endDate":"2021-01-02T15:00:00+00:00","location":{"@type":"Place","name":"Ibrox Stadium","description":"","url":"https://www.scottishevents.co.uk/venue/ibrox-stadium/","address":{"@type":"PostalAddress","streetAddress":"150 Edmiston Drive","addressLocality":"Glasgow","postalCode":"G512XD","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Hibs v Livingstone","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/08/hibs-v-livingston-fixture-badges.png","url":"https://www.scottishevents.co.uk/event/hibs-v-livingstone/","startDate":"2021-01-02T15:00:00+00:00","endDate":"2021-01-02T17:00:00+00:00","location":{"@type":"Place","name":"Hibernian Fc","description":"","url":"https://www.scottishevents.co.uk/venue/hibernian-fc/","address":{"@type":"PostalAddress","streetAddress":"Easter Road","addressLocality":"Edinburgh","postalCode":"EH75QG","addressCountry":"United Kingdom"},"telephone":"","sameAs":""},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Newcastle v Leicester","description":"","image":"https://www.scottishevents.co.uk/wp-content/uploads/2020/08/newcastle-v-leicester-fixture-badge.png","url":"https://www.scottishevents.co.uk/event/newcastle-v-leicester/","startDate":"2021-01-02T15:00:00+00:00","endDate":"2021-01-02T17:00:00+00:00","location":{"@type":"Place","name":"St James Park","description":"","url":"https://www.scottishevents.co.uk/venue/st-james-park/","address":{"@type":"PostalAddress","streetAddress":"Barrack Road","addressLocality":"Newcastle"," ...
#        </script>
#        <script data-js="tribe-events-view-data" type="application/json">
#         {"slug":"list","prev_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/?eventDisplay=past","next_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/page\/2\/","view_class":"Tribe\\Events\\Views\\V2\\Views\\List_View","view_slug":"list","view_label":"List","view":{},"title":"Search Results for &#8220;&#8221; &#8211; Scottish Events","events":[7050,7402,7412,7420,7896,7917,8022,7958,7898,7960,8024,7900],"url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","url_event_date":false,"bar":{"keyword":"","date":""},"today":"2021-01-01 00:00:00","now":"2021-01-01 20:35:17","request_date":{"date":"2021-01-01 00:00:00.000000","timezone_type":3,"timezone":"Europe\/London"},"rest_url":"https:\/\/www.scottishevents.co.uk\/wp-json\/tribe\/views\/v2\/html","rest_nonce":"e355e7b8eb","should_manage_url":true,"today_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","prev_label":"","next_label":"","date_formats":{"compact":"n\/j\/Y","month_and_year_compact":"n\/j\/Y","month_and_year":"F Y","time_range_separator":" - ","date_time_separator":" @ "},"messages":[],"start_of_week":"1","breadcrumbs":[{"link":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","label":"Events"},{"link":"","label":"Sport"}],"before_events":"","after_events":"\n<!--\nThis calendar is powered by The Events Calendar.\nhttp:\/\/m.tri.be\/18wn\n-->\n","display_events_bar":true,"disable_event_search":false,"live_refresh":true,"ical":{"display_link":true,"link":{"url":"https:\/\/www.scottishevents.co.uk\/events\/?ical=1","text":"Export Events","title":"Use this to share calendar data with Google Calendar, Apple iCal and other compatible apps"}},"container_classes":["tribe-common","tribe-events","tribe-events-view","tribe-events-view--list"],"container_data":[],"is_past":false,"breakpoints":{"xsmall":500,"medium":768,"full":960},"breakpoint_pointer":"04b20fe3-144f-475c-8419-91bb683ffff4","is_initial_load":true,"public_views":{"list":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\List_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/list\/","view_label":"List"},"month":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\Month_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/month\/","view_label":"Month"},"day":{"view_class":"Tribe\\Events\\Views\\V2\\Views\\Day_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/today\/","view_label":"Day"},"photo":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Photo_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/photo\/","view_label":"Photo"},"week":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Week_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/week\/","view_label":"Week"},"map":{"view_class":"Tribe\\Events\\Pro\\Views\\V2\\Views\\Map_View","view_url":"https:\/\/www.scottishevents.co.uk\/events\/category\/sport\/map\/","view_label":"Map"}},"show_latest_past":true,"show_now":true,"now_label":"Now","now_label_mobile":"Now","show_end":true,"selected_start_datetime":"2021-01-01","selected_start_date_mobile":"1\/1\/2021","selected_start_date_label":"January 1","selected_end_datetime":"2021-01-27","selected_end_date_mobile":"1\/27\/2021","selected_end_date_label":"January 27","datepicker_date":"1\/1\/2021","json_ld_data":"<script type=\"application\/ld+json\">\r\n[{\"@context\":\"http:\/\/schema.org\",\"@type\":\"Event\",\"name\":\"Ayr Races\",\"description\":\"\",\"image\":\"https:\/\/www.scottishevents.co.uk\/wp-content\/uploads\/2020\/06\/ayr-races.jpg\",\"url\":\"https:\/\/www.scottishevents.co.uk\/event\/ayr-races\/\",\"startDate\":\"2020-09-17T12:00:00+01:00\",\"endDate\":\"2021-09-19T17:00:00+01:00\",\"location\":{\"@type\":\"Place\",\"name\":\"Ayr Racecourse\",\"description\":\"\",\"url\":\"https:\/\/www.scottishevents.co.uk\/venue\/ayr-racecourse\/\",\"address\":{\"@type\": ...
#        </script>
#        <header class="tribe-events-header tribe-events-header--has-event-search">
#         <div class="tribe-events-header__breadcrumbs tribe-events-c-breadcrumbs">
#          <ol class="tribe-events-c-breadcrumbs__list">
#           <li class="tribe-events-c-breadcrumbs__list-item">
#            <a class="tribe-events-c-breadcrumbs__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/">
#             Events
#            </a>
#           </li>
#           <li class="tribe-events-c-breadcrumbs__list-item">
#            <span class="tribe-events-c-breadcrumbs__list-item-text">
#             Sport
#            </span>
#           </li>
#          </ol>
#         </div>
#         <div class="tribe-events-header__events-bar tribe-events-c-events-bar tribe-events-c-events-bar--border" data-js="tribe-events-events-bar">
#          <h2 class="tribe-common-a11y-visual-hide">
#           Events Search and Views Navigation
#          </h2>
#          <button aria-controls="tribe-events-search-filter-container" aria-expanded="false" aria-selected="false" class="tribe-events-c-events-bar__search-button" data-js="tribe-events-search-button">
#           <span class="tribe-events-c-events-bar__search-button-icon tribe-common-svgicon">
#           </span>
#           <span class="tribe-events-c-events-bar__search-button-text tribe-common-a11y-visual-hide">
#            Search
#           </span>
#          </button>
#          <div class="tribe-events-c-events-bar__search-filters-container" data-js="tribe-events-search-filters-container" id="tribe-events-search-filters-container">
#           <div class="tribe-events-c-events-bar__search" data-js="tribe-events-events-bar-tabpanel tribe-events-events-bar-search" id="tribe-events-events-bar-search">
#            <form class="tribe-events-c-search tribe-events-c-events-bar__search-form" data-js="tribe-events-view-form" method="get" role="search">
#             <input id="tribe-events-views[_wpnonce]" name="tribe-events-views[_wpnonce]" type="hidden" value="e355e7b8eb"/>
#             <input name="_wp_http_referer" type="hidden" value="/events/category/sport/list/"/>
#             <input name="tribe-events-views[url]" type="hidden" value="https://www.scottishevents.co.uk/events/category/sport/list/"/>
#             <div class="tribe-events-c-search__input-group">
#              <div class="tribe-common-form-control-text tribe-events-c-search__input-control tribe-events-c-search__input-control--keyword" data-js="tribe-events-events-bar-input-control">
#               <label class="tribe-common-form-control-text__label" for="tribe-events-events-bar-keyword">
#                Enter Keyword. Search for Events by Keyword.
#               </label>
#               <input aria-label="Enter Keyword. Search for events by Keyword." class="tribe-common-form-control-text__input tribe-events-c-search__input tribe-events-c-search__input--icon" data-js="tribe-events-events-bar-input-control-input" id="tribe-events-events-bar-keyword" name="tribe-events-views[tribe-bar-search]" placeholder="Search for events" type="text" value=""/>
#              </div>
#              <div class="tribe-common-form-control-text tribe-events-c-search__input-control tribe-events-c-search__input-control--location" data-js="tribe-events-events-bar-input-control">
#               <label class="tribe-common-form-control-text__label" for="tribe-events-events-bar-location">
#                Enter Location. Search for Events by Location.
#               </label>
#               <input aria-label="Enter Location. Search for Events by Location." class="tribe-common-form-control-text__input tribe-events-c-search__input tribe-events-c-search__input--icon" data-js="tribe-events-events-bar-input-control-input" id="tribe-events-events-bar-location" name="tribe-events-views[tribe-bar-location]" placeholder="In a location" type="text" value=""/>
#              </div>
#             </div>
#             <button class="tribe-common-c-btn tribe-events-c-search__button" name="submit-bar" type="submit">
#              Find Events
#             </button>
#            </form>
#           </div>
#          </div>
#          <div class="tribe-events-c-events-bar__views">
#           <h3 class="tribe-common-a11y-visual-hide">
#            Event Views Navigation
#           </h3>
#           <div class="tribe-events-c-view-selector tribe-events-c-view-selector--labels" data-js="tribe-events-view-selector">
#            <button class="tribe-events-c-view-selector__button" data-js="tribe-events-view-selector-button">
#             <span class="tribe-events-c-view-selector__button-icon tribe-common-svgicon tribe-common-svgicon--list">
#             </span>
#             <span class="tribe-events-c-view-selector__button-text tribe-common-a11y-visual-hide">
#              List
#             </span>
#            </button>
#            <div class="tribe-events-c-view-selector__content" data-js="tribe-events-view-selector-list-container" id="tribe-events-view-selector-content">
#             <ul class="tribe-events-c-view-selector__list">
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--list tribe-events-c-view-selector__list-item--active">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--list">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 List
#                </span>
#               </a>
#              </li>
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--month">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/month/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--month">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 Month
#                </span>
#               </a>
#              </li>
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--day">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/today/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--day">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 Day
#                </span>
#               </a>
#              </li>
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--photo">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/photo/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--photo">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 Photo
#                </span>
#               </a>
#              </li>
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--week">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/week/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--week">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 Week
#                </span>
#               </a>
#              </li>
#              <li class="tribe-events-c-view-selector__list-item tribe-events-c-view-selector__list-item--map">
#               <a class="tribe-events-c-view-selector__list-item-link" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/map/">
#                <span class="tribe-events-c-view-selector__list-item-icon tribe-common-svgicon tribe-common-svgicon--map">
#                </span>
#                <span class="tribe-events-c-view-selector__list-item-text">
#                 Map
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="tribe-events-c-top-bar tribe-events-header__top-bar">
#          <nav class="tribe-events-c-top-bar__nav tribe-common-a11y-hidden">
#           <ul class="tribe-events-c-top-bar__nav-list">
#            <li class="tribe-events-c-top-bar__nav-list-item">
#             <a aria-label="Previous Events" class="tribe-common-c-btn-icon tribe-common-c-btn-icon--caret-left tribe-events-c-top-bar__nav-link tribe-events-c-top-bar__nav-link--prev" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/?eventDisplay=past" title="Previous Events">
#             </a>
#            </li>
#            <li class="tribe-events-c-top-bar__nav-list-item">
#             <a aria-label="Next Events" class="tribe-common-c-btn-icon tribe-common-c-btn-icon--caret-right tribe-events-c-top-bar__nav-link tribe-events-c-top-bar__nav-link--next" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/page/2/" title="Next Events">
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <a aria-label="Click to select today's date" class="tribe-common-c-btn-border tribe-events-c-top-bar__today-button tribe-common-a11y-hidden" data-js="tribe-events-view-link" href="https://www.scottishevents.co.uk/events/category/sport/list/" title="Click to select today's date">
#           Today
#          </a>
#          <div class="tribe-events-c-top-bar__datepicker">
#           <button aria-label="Click to toggle datepicker" class="tribe-common-h3 tribe-common-h--alt tribe-events-c-top-bar__datepicker-button" data-js="tribe-events-top-bar-datepicker-button" title="Click to toggle datepicker" type="button">
#            <time class="tribe-events-c-top-bar__datepicker-time" datetime="2021-01-01">
#             <span class="tribe-events-c-top-bar__datepicker-mobile">
#              Now
#             </span>
#             <span class="tribe-events-c-top-bar__datepicker-desktop tribe-common-a11y-hidden">
#              Now
#             </span>
#            </time>
#            <span class="tribe-events-c-top-bar__datepicker-separator">
#             -
#            </span>
#            <time class="tribe-events-c-top-bar__datepicker-time" datetime="2021-01-27">
#             <span class="tribe-events-c-top-bar__datepicker-mobile">
#              1/27/2021
#             </span>
#             <span class="tribe-events-c-top-bar__datepicker-desktop tribe-common-a11y-hidden">
#              January 27
#             </span>
#            </time>
#           </button>
#           <label class="tribe-events-c-top-bar__datepicker-label tribe-common-a11y-visual-hide" for="tribe-events-top-bar-date">
#            Select date.
#           </label>
#           <input autocomplete="off" class="tribe-events-c-top-bar__datepicker-input tribe-common-a11y-visual-hide" data-js="tribe-events-top-bar-date" id="tribe-events-top-bar-date" name="tribe-events-views[tribe-bar-date]" readonly="readonly" tabindex="-1" type="text" value="1/1/2021"/>
#           <div class="tribe-events-c-top-bar__datepicker-container" data-js="tribe-events-top-bar-datepicker-container">
#           </div>
#          </div>
#          <div class="tribe-events-c-top-bar__actions tribe-common-a11y-hidden">
#          </div>
#         </div>
#        </header>
#        <div class="tribe-events-calendar-list">
#         <div class="tribe-events-calendar-list__month-separator">
#          <time class="tribe-events-calendar-list__month-separator-text tribe-common-h7 tribe-common-h6--min-medium tribe-common-h--alt" datetime="2021-01">
#           January 2021
#          </time>
#         </div>
#         <div class="tribe-common-g-row tribe-events-calendar-list__event-row">
#          <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#           <time class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2021-01-01">
#            <span class="tribe-events-calendar-list__event-date-tag-weekday">
#             Fri
#            </span>
#            <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#             1
#            </span>
#           </time>
#          </div>
#          <div class="tribe-events-calendar-list__event-wrapper tribe-common-g-col">
#           <article class="tribe-events-calendar-list__event tribe-common-g-row tribe-common-g-row--gutters post-7050 tribe_events type-tribe_events status-publish has-post-thumbnail hentry tribe_events_cat-event tribe_events_cat-horse-racing tribe_events_cat-sport cat_event cat_horse-racing cat_sport">
#            <div class="tribe-events-calendar-list__event-featured-image-wrapper tribe-common-g-col">
#             <a class="tribe-events-calendar-list__event-featured-image-link" href="https://www.scottishevents.co.uk/event/ayr-races/" rel="bookmark" title="Ayr Races">
#              <img class="tribe-events-calendar-list__event-featured-image" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/06/ayr-races.jpg" title="ayr races"/>
#             </a>
#            </div>
#            <div class="tribe-events-calendar-list__event-details tribe-common-g-col">
#             <header class="tribe-events-calendar-list__event-header">
#              <div class="tribe-events-calendar-list__event-datetime-wrapper tribe-common-b2">
#               <time class="tribe-events-calendar-list__event-datetime" datetime="2020-09-17">
#                <span class="tribe-event-date-start">
#                 17 September 2020 @ 12:00 pm
#                </span>
#                -
#                <span class="tribe-event-date-end">
#                 19 September 2021 @ 5:00 pm
#                </span>
#               </time>
#              </div>
#              <h3 class="tribe-events-calendar-list__event-title tribe-common-h6 tribe-common-h4--min-medium">
#               <a class="tribe-events-calendar-list__event-title-link tribe-common-anchor-thin" href="https://www.scottishevents.co.uk/event/ayr-races/" rel="bookmark" title="Ayr Races">
#                Ayr Races
#               </a>
#              </h3>
#              <address class="tribe-events-calendar-list__event-venue tribe-common-b2">
#               <span class="tribe-events-calendar-list__event-venue-title tribe-common-b2--bold">
#                Ayr Racecourse
#               </span>
#               <span class="tribe-events-calendar-list__event-venue-address">
#                Whitletts Road, 					Ayr
#               </span>
#              </address>
#             </header>
#            </div>
#           </article>
#          </div>
#         </div>
#         <div class="tribe-common-g-row tribe-events-calendar-list__event-row">
#          <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#           <time class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2021-01-01">
#            <span class="tribe-events-calendar-list__event-date-tag-weekday">
#             Fri
#            </span>
#            <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#             1
#            </span>
#           </time>
#          </div>
#          <div class="tribe-events-calendar-list__event-wrapper tribe-common-g-col">
#           <article class="tribe-events-calendar-list__event tribe-common-g-row tribe-common-g-row--gutters post-7402 tribe_events type-tribe_events status-publish has-post-thumbnail hentry tribe_events_cat-football-tickets tribe_events_cat-glasgow tribe_events_cat-rangers tribe_events_cat-sport cat_football-tickets cat_glasgow cat_rangers cat_sport">
#            <div class="tribe-events-calendar-list__event-featured-image-wrapper tribe-common-g-col">
#             <a class="tribe-events-calendar-list__event-featured-image-link" href="https://www.scottishevents.co.uk/event/rangers-v-hamilton-academicals/" rel="bookmark" title="Rangers v Hamilton Academicals">
#              <img class="tribe-events-calendar-list__event-featured-image" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge.png" srcset="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge-300x200.png 300w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge-360x240.png 360w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-hamilton-fixture-badge.png 450w" title="rangers-v-hamilton-fixture-badge"/>
#             </a>
#            </div>
#            <div class="tribe-events-calendar-list__event-details tribe-common-g-col">
#             <header class="tribe-events-calendar-list__event-header">
#              <div class="tribe-events-calendar-list__event-datetime-wrapper tribe-common-b2">
#               <time class="tribe-events-calendar-list__event-datetime" datetime="2020-11-06">
#                <span class="tribe-event-date-start">
#                 6 November 2020 @ 7:30 pm
#                </span>
#                -
#                <span class="tribe-event-date-end">
#                 6 August 2021 @ 9:30 pm
#                </span>
#               </time>
#              </div>
#              <h3 class="tribe-events-calendar-list__event-title tribe-common-h6 tribe-common-h4--min-medium">
#               <a class="tribe-events-calendar-list__event-title-link tribe-common-anchor-thin" href="https://www.scottishevents.co.uk/event/rangers-v-hamilton-academicals/" rel="bookmark" title="Rangers v Hamilton Academicals">
#                Rangers v Hamilton Academicals
#               </a>
#              </h3>
#              <address class="tribe-events-calendar-list__event-venue tribe-common-b2">
#               <span class="tribe-events-calendar-list__event-venue-title tribe-common-b2--bold">
#                Ibrox Stadium
#               </span>
#               <span class="tribe-events-calendar-list__event-venue-address">
#                150 Edmiston Drive, 					Glasgow
#               </span>
#              </address>
#             </header>
#            </div>
#           </article>
#          </div>
#         </div>
#         <div class="tribe-common-g-row tribe-events-calendar-list__event-row">
#          <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#           <time class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2021-01-01">
#            <span class="tribe-events-calendar-list__event-date-tag-weekday">
#             Fri
#            </span>
#            <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#             1
#            </span>
#           </time>
#          </div>
#          <div class="tribe-events-calendar-list__event-wrapper tribe-common-g-col">
#           <article class="tribe-events-calendar-list__event tribe-common-g-row tribe-common-g-row--gutters post-7412 tribe_events type-tribe_events status-publish has-post-thumbnail hentry tribe_events_cat-football-tickets tribe_events_cat-glasgow tribe_events_cat-rangers tribe_events_cat-sport cat_football-tickets cat_glasgow cat_rangers cat_sport">
#            <div class="tribe-events-calendar-list__event-featured-image-wrapper tribe-common-g-col">
#             <a class="tribe-events-calendar-list__event-featured-image-link" href="https://www.scottishevents.co.uk/event/rangers-v-motherwell/" rel="bookmark" title="Rangers v Motherwell">
#              <img class="tribe-events-calendar-list__event-featured-image" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge.png" srcset="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge-300x200.png 300w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge-360x240.png 360w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-motherwell-fixture-badge.png 450w" title="rangers-v-motherwell-fixture-badge"/>
#             </a>
#            </div>
#            <div class="tribe-events-calendar-list__event-details tribe-common-g-col">
#             <header class="tribe-events-calendar-list__event-header">
#              <div class="tribe-events-calendar-list__event-datetime-wrapper tribe-common-b2">
#               <time class="tribe-events-calendar-list__event-datetime" datetime="2020-12-19">
#                <span class="tribe-event-date-start">
#                 19 December 2020 @ 3:00 pm
#                </span>
#                -
#                <span class="tribe-event-date-end">
#                 19 December 2021 @ 5:00 pm
#                </span>
#               </time>
#              </div>
#              <h3 class="tribe-events-calendar-list__event-title tribe-common-h6 tribe-common-h4--min-medium">
#               <a class="tribe-events-calendar-list__event-title-link tribe-common-anchor-thin" href="https://www.scottishevents.co.uk/event/rangers-v-motherwell/" rel="bookmark" title="Rangers v Motherwell">
#                Rangers v Motherwell
#               </a>
#              </h3>
#              <address class="tribe-events-calendar-list__event-venue tribe-common-b2">
#               <span class="tribe-events-calendar-list__event-venue-title tribe-common-b2--bold">
#                Ibrox Stadium
#               </span>
#               <span class="tribe-events-calendar-list__event-venue-address">
#                150 Edmiston Drive, 					Glasgow
#               </span>
#              </address>
#             </header>
#            </div>
#           </article>
#          </div>
#         </div>
#         <div class="tribe-common-g-row tribe-events-calendar-list__event-row">
#          <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#           <time class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2021-01-02">
#            <span class="tribe-events-calendar-list__event-date-tag-weekday">
#             Sat
#            </span>
#            <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#             2
#            </span>
#           </time>
#          </div>
#          <div class="tribe-events-calendar-list__event-wrapper tribe-common-g-col">
#           <article class="tribe-events-calendar-list__event tribe-common-g-row tribe-common-g-row--gutters post-7420 tribe_events type-tribe_events status-publish has-post-thumbnail hentry tribe_events_cat-football-tickets tribe_events_cat-glasgow tribe_events_cat-rangers tribe_events_cat-sport cat_football-tickets cat_glasgow cat_rangers cat_sport">
#            <div class="tribe-events-calendar-list__event-featured-image-wrapper tribe-common-g-col">
#             <a class="tribe-events-calendar-list__event-featured-image-link" href="https://www.scottishevents.co.uk/event/rangers-v-celtic/" rel="bookmark" title="Rangers v Celtic">
#              <img class="tribe-events-calendar-list__event-featured-image" src="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge.png" srcset="https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge-300x200.png 300w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge-360x240.png 360w, https://www.scottishevents.co.uk/wp-content/uploads/2020/07/rangers-v-celtic-fixture-badge.png 450w" title="rangers-v-celtic-fixture-badge"/>
#             </a>
#            </div>
#            <div class="tribe-events-calendar-list__event-details tribe-common-g-col">
#             <header class="tribe-events-calendar-list__event-header">
#              <div class="tribe-events-calendar-list__event-datetime-wrapper tribe-common-b2">
#               <time class="tribe-events-calendar-list__event-datetime" datetime="2021-01-02">
#                <span class="tribe-event-date-start">
#                 January 2 @ 12:30 pm
#                </span>
#                -
#                <span class="tribe-event-time">
#                 3:00 pm
#                </span>
#               </time>
#              </div>
#              <h3 class="tribe-events-calendar-list__event-title tribe-common-h6 tribe-common-h4--min-medium">
#               <a class="tribe-events-calendar-list__event-title-link tribe-common-anchor-thin" href="https://www.scottishevents.co.uk/event/rangers-v-celtic/" rel="bookmark" title="Rangers v Celtic">
#                Rangers v Celtic
#               </a>
#              </h3>
#              <address class="tribe-events-calendar-list__event-venue tribe-common-b2">
#               <span class="tribe-events-calendar-list__event-venue-title tribe-common-b2--bold">
#                Ibrox Stadium
#               </span>
#               <span class="tribe-events-calendar-list__event-venue-address">
#                150 Edmiston Drive, 					Glasgow
#               </span>
#              </address>
#             </header>
#            </div>
#           </article>
#          </div>
#         </div>
#         <div class="tribe-common-g-row tribe-events-calendar-list__event-row">
# ...
#        Create an Account!
#       </a>
#      </div>
#      <input class="required" id="username" name="username" placeholder="Username" type="text"/>
#     </div>
#     <div>
#      <label for="password">
#       Password
#      </label>
#      <input class="required" id="password" name="password" placeholder="Password" type="password"/>
#     </div>
#     <input class="button" name="login" type="submit" value="Login"/>
#     <a class="text-link" href="https://www.scottishevents.co.uk/my-account/lost-password/" id="pop_forgot">
#      Forgot Password?
#     </a>
#     <a class="close" href="#">
#      <span aria-hidden="true">
#       ×
#      </span>
#     </a>
#    </input>
#   </input>
#  </form>
#  <form action="register" class="ticketbox-ajax-auth" id="ticketbox-ajax-auth-register" method="post">
#   <div class="alert alert-warning">
#    Registration is disabled.
#   </div>
#   <hr/>
#   <a class="text-link" id="pop_login" style="cursor:pointer">
#    Want to Login?
#   </a>
#   <a class="close" href="#">
#    <span aria-hidden="true">
#     ×
#    </span>
#   </a>
#  </form>
#  <form action="forgot_password" class="ticketbox-ajax-auth" id="ticketbox-ajax-auth-forgot_password" method="post">
#   <h1>
#    Forgot Password?
#   </h1>
#   <hr/>
#   <p class="status">
#   </p>
#   <input id="forgotsecurity" name="forgotsecurity" type="hidden" value="97ca8c0c99">
#    <input name="_wp_http_referer" type="hidden" value="/events/category/sport/list/">
#     <div>
#      <label for="user_login">
#       Username or Email
#      </label>
#      <input class="required" id="user_login" name="user_login" placeholder="Username or email" type="text"/>
#     </div>
#     <input class="button" name="forgot_password" type="submit" value="Get Password"/>
#     <a class="close" href="#" style="cursor:pointer">
#      <span aria-hidden="true">
#       ×
#      </span>
#     </a>
#    </input>
#   </input>
#  </form>
#  <script>
#   /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"},"registration_prompt":"There is unsaved attendee information. Are you sure you want to continue?"};/* ]]> */
#  </script>
#  <script type="text/javascript">
#   var c = document.body.className;
# 		c = c.replace(/woocommerce-no-js/, 'woocommerce-js');
# 		document.body.className = c;
#  </script>
#  <link href="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/css/widget-theme.min.css?ver=5.1.1" id="widget-calendar-pro-style-css" media="all" rel="stylesheet" type="text/css"/>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/vendor/bootstrap-datepicker/js/bootstrap-datepicker.min.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/vendor/jquery.cookie/jquery.cookie.js?ver=4.12.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/vendor/jquery.deparam/jquery.deparam.js?ver=4.12.1" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var TribeTicketsPlus = {"ajaxurl":"https:\/\/www.scottishevents.co.uk\/wp-admin\/admin-ajax.php","save_attendee_info_nonce":"9b3d89b410"};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/src/resources/js/meta.min.js?ver=4.12.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets-plus/src/resources/js/attendees-list.min.js?ver=4.12.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-includes/js/jquery/ui/draggable.min.js?ver=1.11.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/vendor/nanoscroller/jquery.nanoscroller.min.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-grid-scroller.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/datepicker.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/datepicker-pro.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/toggle-recurrence.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/js/ticket-details.min.js?ver=4.12.2" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/vendor/tooltipster/tooltipster.bundle.min.js?ver=4.12.5" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/tooltip.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/tooltip-pro.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/src/resources/js/rsvp.min.js?ver=4.12.2" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/multiday-events.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/multiday-events-pro.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-no-venue-modal.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/vendor/swiper/dist/js/swiper.min.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-provider-google-maps.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/accordion.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-multiday-toggle.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-event-link.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-events-scroller.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/week-day-selector.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/views/map-events.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/event-tickets/common/src/resources/js/utils/query-string.js?ver=4.12.5" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/viewport.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/view-selector.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/navigation-scroll.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/month-mobile-events.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/month-grid.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/events-bar.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/events-bar-inputs.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/the-events-calendar/src/resources/js/views/manager.js?ver=5.1.4" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.scottishevents.co.uk\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.9" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/js-cookie/js.cookie.min.js?ver=2.1.4" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var woocommerce_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%"};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/frontend/woocommerce.min.js?ver=4.1.0" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var wc_cart_fragments_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","cart_hash_key":"wc_cart_hash_23d62af59e1a03a30f100f510c63c31a","fragment_name":"wc_fragments_23d62af59e1a03a30f100f510c63c31a","request_timeout":"5000"};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/woocommerce/assets/js/frontend/cart-fragments.min.js?ver=4.1.0" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var dt_megamenu = {"ajax_url":"https:\/\/www.scottishevents.co.uk\/wp-admin\/admin-ajax.php","ajax_loader":"","ajax_enabled":"0"};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/includes/megamenu/js/megamenu.min.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/js/bootstrap.min.js?ver=3.5.5" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/chosen/ajax-chosen.jquery.min.js?ver=1.0.0" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.appear.min.js?ver=1.0.0" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/typed.min.js?ver=1.0.0" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/easing.min.js?ver=1.3.0" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/waypoints.min.js?ver=2.0.5" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.countTo.min.js?ver=2.0.2" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.transit.min.js?ver=0.9.12" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/ProgressCircle.min.js?ver=2.0.2" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/magnific-popup/jquery.magnific-popup.min.js?ver=0.9.9" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/plugins/events-calendar-pro/src/resources/js/widget-countdown.min.js?ver=5.1.1" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/owlcarousel/owl.carousel.min.js?ver=2.3.2" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/helpers/jquery.ba-throttle-debounce.min.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/jquery.browser.min.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/anime.min.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/scrollMonitor.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/BlockRevealers/js/main.min.js?ver=5.4.4" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/lib/js/plugins.js?ver=1.2.9.7" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /* <![CDATA[ */
# var DawnThemesL10n = {"ajax_url":"\/wp-admin\/admin-ajax.php","protocol":"https","navbarFixedHeight":"50","breakpoint":"900","nav_breakpoint":"900","is_mobile_theme":"no","cookie_path":"\/","screen_sm":"768","screen_md":"992","screen_lg":"1200","next":"Next","prev":"Prev","touch_animate":"1","logo_retina":"","ajax_finishedMsg":"All posts displayed","ajax_msgText":"Loading the next set of posts...","woocommerce":"1","imageLazyLoading":"1","add_to_wishlist_text":"","user_logged_in":"0","loadingmessage":"Sending info, please wait..."};
# /* ]]> */
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-content/themes/ticketbox/assets/js/script.min.js?ver=1.2.9.7" type="text/javascript">
#  </script>
#  <script src="https://www.scottishevents.co.uk/wp-includes/js/wp-embed.min.js?ver=5.4.4" type="text/javascript">
#  </script>
# </body>

# %%
event_tag='tribe-events-calendar-list__event-title tribe-common-h6 tribe-common-h4--min-medium'

# %%
event=[]
for item in page_soup.body.find_all('h3', {'class':event_tag}):
    event.append(item.text.strip())
    print (item.text.strip())
# Out:
# Ayr Races
# Rangers v Hamilton Academicals
# Rangers v Motherwell
# Rangers v Celtic
# Hibs v Livingstone
# Newcastle v Leicester
# Man Utd v Aston Villa
# Man City v Brighton
# Hibs v Kilmarnock
# Man City v Crystal Palace
# Man Utd v Sheffield United
# Hibs v Rangers

# %%
location='tribe-events-calendar-list__event-venue-title tribe-common-b2--bold'

# %%
place=[]
for loc in page_soup.body.findAll('span', {'class':location}):
    place.append(loc.text.strip())
    print (loc.text.strip())
# Out:
# Ayr Racecourse
# Ibrox Stadium
# Ibrox Stadium
# Ibrox Stadium
# Hibernian Fc
# St James Park
# Manchester United Football Club
# Manchester City Football Club
# Hibernian Fc
# Manchester City Football Club
# Manchester United Football Club
# Hibernian Fc

# %%
# geting the address
address=[]
add='tribe-events-calendar-list__event-venue-address'
for add in page_soup.body.findAll('span', {'class':add}):
    address.append(add.text.strip().split(',')[0])
    print (add.text.strip().split(',')[0])
# Out:
# Whitletts Road
# 150 Edmiston Drive
# 150 Edmiston Drive
# 150 Edmiston Drive
# Easter Road
# Barrack Road
# Old Trafford
# Etihad Stadium
# Easter Road
# Etihad Stadium
# Old Trafford
# Easter Road

# %%
# getting the cities
city =[]
add='tribe-events-calendar-list__event-venue-address'
for add in page_soup.body.findAll('span', {'class':add}):
    city.append(add.text.strip().split(',')[-1].strip())
    print (add.text.strip().split(',')[-1].strip())
# Out:
# Ayr
# Glasgow
# Glasgow
# Glasgow
# Edinburgh
# Newcastle
# Manchester
# Manchester
# Edinburgh
# Manchester
# Manchester
# Edinburgh

# %%
datetime="tribe-events-calendar-list__event-datetime"
startdate=[]
for date in page_soup.body.find_all('time', {'class':datetime}):
    startdate.append(date.text.strip().split('@')[0].strip())

# %%
enddate=[]
for date in page_soup.body.find_all('time', {'class':datetime}):
    enddate.append(date.text.strip().split('-')[1][:-9].strip())

# %%
start_time=[]
for date in page_soup.body.find_all('time', {'class':datetime}):
    start_time.append(date.text.strip().split('@')[1][:9].strip())

# %%
end_time=[]
for date in page_soup.body.find_all('time', {'class':datetime}):
         (end_time.append(re.split('@|-',date.text)[-1].strip()))

# %%
end_time
# Out:
# ['5:00 pm',
#  '9:30 pm',
#  '5:00 pm',
#  '3:00 pm',
#  '5:00 pm',
#  '5:00 pm',
#  '5:00 pm',
#  '10:00 pm',
#  '5:00 pm',
#  '10:00 pm',
#  '10:00 pm',
#  '9:30 pm']

# %%
df= pd.DataFrame({'event':event,'location':place,'address':address, 'city':city, 'start_date':startdate,
                 'end_date': enddate, 'start_time':start_time, 'end_time':end_time})

# %%
df
# Out:
#                              event                         location  \
# 0                        Ayr Races                   Ayr Racecourse
# 1   Rangers v Hamilton Academicals                    Ibrox Stadium
# 2             Rangers v Motherwell                    Ibrox Stadium
# 3                 Rangers v Celtic                    Ibrox Stadium
# 4               Hibs v Livingstone                     Hibernian Fc
# 5            Newcastle v Leicester                    St James Park
# 6            Man Utd v Aston Villa  Manchester United Football Club
# 7              Man City v Brighton    Manchester City Football Club
# 8                Hibs v Kilmarnock                     Hibernian Fc
# 9        Man City v Crystal Palace    Manchester City Football Club
# 10      Man Utd v Sheffield United  Manchester United Football Club
# 11                  Hibs v Rangers                     Hibernian Fc
#
#                address        city         start_date           end_date  \
# 0       Whitletts Road         Ayr  17 September 2020  19 September 2021
# 1   150 Edmiston Drive     Glasgow    6 November 2020      6 August 2021
# 2   150 Edmiston Drive     Glasgow   19 December 2020   19 December 2021
# 3   150 Edmiston Drive     Glasgow          January 2
# 4          Easter Road   Edinburgh          January 2
# 5         Barrack Road   Newcastle          January 2
# 6         Old Trafford  Manchester          January 2
# 7       Etihad Stadium  Manchester         January 13
# 8          Easter Road   Edinburgh         January 16
# 9       Etihad Stadium  Manchester         January 26
# 10        Old Trafford  Manchester         January 26
# 11         Easter Road   Edinburgh         January 27
#
#    start_time  end_time
# 0    12:00 pm   5:00 pm
# 1     7:30 pm   9:30 pm
# 2     3:00 pm   5:00 pm
# 3    12:30 pm   3:00 pm
# 4     3:00 pm   5:00 pm
# 5     3:00 pm   5:00 pm
# 6     3:00 pm   5:00 pm
# 7     8:00 pm  10:00 pm
# 8     3:00 pm   5:00 pm
# 9     8:00 pm  10:00 pm
# 10    8:00 pm  10:00 pm
# 11    7:30 pm   9:30 pm

# %%
df['end_date'][3:]=df['start_date'][3:]

# %%
df
# Out:
#                              event                         location  \
# 0                        Ayr Races                   Ayr Racecourse
# 1   Rangers v Hamilton Academicals                    Ibrox Stadium
# 2             Rangers v Motherwell                    Ibrox Stadium
# 3                 Rangers v Celtic                    Ibrox Stadium
# 4               Hibs v Livingstone                     Hibernian Fc
# 5            Newcastle v Leicester                    St James Park
# 6            Man Utd v Aston Villa  Manchester United Football Club
# 7              Man City v Brighton    Manchester City Football Club
# 8                Hibs v Kilmarnock                     Hibernian Fc
# 9        Man City v Crystal Palace    Manchester City Football Club
# 10      Man Utd v Sheffield United  Manchester United Football Club
# 11                  Hibs v Rangers                     Hibernian Fc
#
#                address        city         start_date           end_date  \
# 0       Whitletts Road         Ayr  17 September 2020  19 September 2021
# 1   150 Edmiston Drive     Glasgow    6 November 2020      6 August 2021
# 2   150 Edmiston Drive     Glasgow   19 December 2020   19 December 2021
# 3   150 Edmiston Drive     Glasgow          January 2          January 2
# 4          Easter Road   Edinburgh          January 2          January 2
# 5         Barrack Road   Newcastle          January 2          January 2
# 6         Old Trafford  Manchester          January 2          January 2
# 7       Etihad Stadium  Manchester         January 13         January 13
# 8          Easter Road   Edinburgh         January 16         January 16
# 9       Etihad Stadium  Manchester         January 26         January 26
# 10        Old Trafford  Manchester         January 26         January 26
# 11         Easter Road   Edinburgh         January 27         January 27
#
#    start_time  end_time
# 0    12:00 pm   5:00 pm
# 1     7:30 pm   9:30 pm
# 2     3:00 pm   5:00 pm
# 3    12:30 pm   3:00 pm
# 4     3:00 pm   5:00 pm
# 5     3:00 pm   5:00 pm
# 6     3:00 pm   5:00 pm
# 7     8:00 pm  10:00 pm
# 8     3:00 pm   5:00 pm
# 9     8:00 pm  10:00 pm
# 10    8:00 pm  10:00 pm
# 11    7:30 pm   9:30 pm

# %%
# change into csv
df.to_csv('web_scrapping1.csv')
